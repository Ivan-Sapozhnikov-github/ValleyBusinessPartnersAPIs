# %%
# pip install openai

# %%
# executive_summary = """ Executive Summary
# Power House Energy Consulting represents a unique opportunity to acquire the dominant HERS
# rating and building energy consulting company in Western Massachusetts, positioned at the center of
# the nation's most aggressive building decarbonization mandate. Founded in 2011 when virtually no
# homes required energy ratings, Power House has grown to become the leader in its territory by
# developing strong customer relationships along with a reputation for delivering results.
# Investment Highlights
# Power House generates nearly $800,000 in annual revenue with nearly 50% bottom-line
# EBITDA margins, serving over hundreds of projects annually across residential new construction,
# renovations, and high-performance building certifications. The company's revenue model benefits from
# regulatory mandates requiring HERS ratings for 92% of new Massachusetts homes, creating nondiscretionary demand with strong visibility and recurring customer relationships.
# Market Leadership & Competitive Landscape
# As a certified Mass Save partner, Power House assists customers in obtaining tens of thousands
# annually in rebates and incentives directly to clients. The company's technical certifications and
# established builder relationships creates significant barriers to entry in the relationship-driven HERS
# industry.
# The February 2023 strategic acquisition of HIS & HERS Energy Efficiency expanded Power House's
# capabilities into multi-family projects and premium above-code certifications (Passive House, ZERH,
# Energy Star), strengthening margins and positioning the company as a comprehensive “building science
# consultant” rather than just a testing service.
# Growth Trajectory & Expansion Opportunity
# Power House operates in a regulation-driven market supported by Massachusetts' $4.5 billion Mass Save
# budget (2025-2027) and legally mandated net-zero emissions target by 2050. Recent changes to the
# federal policy have had no significant impact on the core revenue for Powerhouse as Massachusetts has
# confirmed its commitment to all certification programs and rebate structures. Recent Stretch Code
# updates have expanded HERS requirements to major renovations, while proposed "HERS ratings at time
# of purchase" legislation could create massive recurring revenue from existing housing stock.
# Geographic expansion opportunities include Worcester metropolitan area and Hartford County,
# Connecticut—both experiencing robust low-rise multi-family growth. The company's operational model
# scales efficiently with minimal capital requirements, as field raters operate from home bases using
# company-provided equipment. """

# %%
openAi_key = ""

# %%
# from openai import OpenAI

# client = OpenAI(
#   api_key=openAi_key
# )

# response = client.responses.create(
#   model="gpt-5-nano",
#   input=f"give me a list of 10 individual key words (comma seperated) based on this executive summary about the business. I want the key words to be one word long and to be centered around the industry, product, and any other one-word key words that grants might have:{executive_summary}",
#   store=True,
# )

# print(response.output_text);

# %%
response.output_text.split(', ')
